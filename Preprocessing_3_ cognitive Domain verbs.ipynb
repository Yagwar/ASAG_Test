# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import f1_score

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.naive_bayes import GaussianNB

# %%
# fuente: https://stackabuse.com/levenshtein-distance-and-text-similarity-in-python/
def levenshtein_dist(seqa, seqb):
    seq1=seqa.lower()
    seq2=seqb.lower()
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )
#     print (matrix)
    return (matrix[size_x - 1, size_y - 1])

# %%
train_questions=pd.read_csv("train_questions.csv", sep=";",index_col=0)
test_questions=pd.read_csv("test_questions.csv", sep=";",index_col=0)

# %%
domain_verbs={"Remember":["Remember","list","locate","name","recognize","state","describe","recall","repeat","retrieve"],
              "Understand":["Understand","conclude","define","illustrate","predict","tell","identify","paraphrase","summarize","categorize","classify","discuss","match","sort","compare","contrast","explain"],
              "Apply":["apply",],
              "Analyze":["analyze"],
              "Evaluate":["evaluate"],
              "Create":["create"]}

# %%
# domain_verbs={"Remember":["Remember","RECOGNIZe","identify","RECALL","retrieve","Choose","Define","Find","How","Label","List","Match","Name","Omit","Recall","Relate","Select","Show","Spell","Tell","What","When","Where","Which","Who","Why","describe"],
#               "Understand":["Understand","INTERPRET","clarify","paraphrase","represent","translate","EXEMPLIFY","illustrate","instantiate","CLASSIFY","categorize","subsume","SUMMARIZe","abstract","generalize","INFERR","conclude","extrapolate","interpolate","predice","COMPARe","contrast","map","match","EXPLAIN","construct models","Classify","Compare","Contrast","Demonstrate","Extend","Illustrate","Infer","Interpret","Outline","Relate","Rephrase","Show","Summarize","Translate"],
#               "Apply":["EXECUTe","carry out","IMPLEMENT","use","Apply","Build","Choose","Construct","Develop","Experiment with","Identify","Interview","Make use of","Model","Organize","Plan","Select","Solve","Utilize"],
#               "Analyze":["DIFFERENTIATe","discriminate","distinguish","focus","select","ORGANIZe","find","coherence","intergrate","outline","parse","structure","ATTRIBUTe","deconstruct","Analyze","Assume","Categorize","Classify","Compare","Conclusion","Contrast","Discover","Dissect","Distinguish","Divide","Examine","Function","Infere","Inspect","List","Motive","Relation","Simplify","Survey","Take part in","Test for","Theme"],
#               "Evaluate":["CHECK","coordinate","detect","monitor","test","CRITIQUe","judge","Agree","Appraise","Assess","Award","Choose","Compare","Conclude","Criteria","Criticize","Decide","Deduct","Defend","Determine","Disprove","Estimate","Evaluate","Explain","Importance","Influence","Interpret","Judge","Justify","Mark","Measure","Opinion","Perceive","Prioritize","Prove","Rate","Recommend","Rule on","Select","Support","Value"],
#               "Create":["GENERATe","hypothesize","PLAN","design","PRODUCe","construct","Adapt","Build","Change","Choose","Combine","Compile","Compose","Construct","Create","Delete","Design","Develop","Discuss","Elaborate","Estimate","Formulate","Happen","Imagine","Improve","Invent","Make up","Maximize","Minimize","Modify","Original","Originate","Plan","Predict","Propose","Solution","Solve","Suppose","Test","Theory"]}

# %%
# vectorizer = CountVectorizer()
tokenize=CountVectorizer().build_tokenizer()

# %%
domain_verb=[]
for domain, verbs in domain_verbs.items():
    for verb in verbs:
        domain_verb.append([domain.lower(),verb.lower()])
domain_verb=np.array(domain_verb)

# %%
preg_num=25

# %%
train_questions.question[preg_num]
# Out:
# "When Sarah did the chromatography test, she saw that one black ink stayed black and didn't separate. She discovered that she had used a permanent marker. She wondered what would happen if she used a different liquid. She wrote in her science notebook, What if I used vinegar in place of the water? Can I get the pigments in permanent ink to separate? How will Sarah know if vinegar separated the permanent ink?"

# %%
domain_proposed=[]

for process_question in train_questions.question:
    distances=[]
    for i,verb in enumerate(domain_verb):
        for tk_quest in tokenize(process_question):
            distances.append([verb[0],verb[1],tk_quest,levenshtein_dist(verb[1],tk_quest)])
    print(process_question)
    distances_df=pd.DataFrame(np.array(distances), columns=["domain", "verb", "question", "distance"])
    distances_df.distance=distances_df.distance.astype('float32')
    freqs=pd.crosstab(distances_df[distances_df.distance<2].sort_values(by=['distance']).domain, columns="count")
    domain_proposed.append(freqs.sort_values(by="count", ascending=False).index[0])
    
    print(distances_df[distances_df.distance<2].sort_values(by=['distance']))
# Out:
# You used several methods to separate and identify the substances in mock rocks. How did you separate the salt from the water?
#           domain      verb  question  distance
# 51      remember  identify  identify       0.0
# 189     remember       how       How       0.0
# 1701       apply  identify  identify       0.0
# 387     remember      show       How       1.0
# 1421  understand      show       How       1.0
# 1541       apply       use      used       1.0
# You used several methods to separate and identify the substances in mock rocks. How did you know the crystals were salt?
#           domain      verb  question  distance
# 49      remember  identify  identify       0.0
# 181     remember       how       How       0.0
# 1624       apply  identify  identify       0.0
# 370     remember      show       How       1.0
# 481     remember     where      were       1.0
# 1357  understand      show       How       1.0
# 1471       apply       use      used       1.0
# Ms. Teridann, a geologist, made a chart showing the scratch-test data for 3 minerals (Mineral X, Mineral Y, and Mineral Z). She wrote "yes" if the tool scratched the mineral and wrote "no" if it did not scratch it. Topaz is a mineral that cannot be scratched by a fingernail, a penny, or a paperclip. How hard is topaz compared to minerals X, Y, and Z? Explain how you know.
#            domain     verb  question  distance
# 510      remember      how       How       0.0
# 519      remember      how       how       0.0
# 3012   understand  explain   Explain       0.0
# 7374     evaluate     test      test       0.0
# 8522     evaluate  explain   Explain       0.0
# 11724      create     test      test       0.0
# 1032     remember     show       How       1.0
# 1041     remember     show       how       1.0
# 1197     remember     what      that       1.0
# 2776   understand  compare  compared       1.0
# 3182   understand  compare  compared       1.0
# 3758   understand     show       How       1.0
# 3767   understand     show       how       1.0
# 6082      analyze  compare  compared       1.0
# 7880     evaluate  compare  compared       1.0
# Georgia found one brown mineral and one black mineral. How can she test them for hardness using only the 2 minerals (no tools)?
#           domain   verb question  distance
# 185     remember    how      How       0.0
# 2806    evaluate   test     test       0.0
# 4456      create   test     test       0.0
# 383     remember   show      How       1.0
# 1417  understand   show      How       1.0
# 2697     analyze  theme     them       1.0
# Georgia found one brown mineral and one black mineral. How will she know which one is harder?
#           domain   verb question  distance
# 145     remember    how      How       0.0
# 404     remember  which    which       0.0
# 298     remember   show      How       1.0
# 1097  understand   show      How       1.0
# If Phil, a geologist, wants to test for calcite while in the field, what should he bring with him? (an acid such as vinegar). Describe what Phil should do to test for calcite and what he would observe.
#         domain      verb  question  distance
# 752   remember      what      what       0.0
# 764   remember      what      what       0.0
# 773   remember      what      what       0.0
# 985   remember  describe  Describe       0.0
# 4704  evaluate      test      test       0.0
# 4728  evaluate      test      test       0.0
# 7479    create      test      test       0.0
# 7503    create      test      test       0.0
# Describe how you can tell the difference between the crystals from the calcite test and salt crystals when you observe them in an evaporation dish.
#           domain      verb  question  distance
# 201     remember       how       how       0.0
# 479     remember      tell      tell       0.0
# 542     remember      when      when       0.0
# 650     remember  describe  Describe       0.0
# 3188    evaluate      test      test       0.0
# 5063      create      test      test       0.0
# 426     remember      show       how       1.0
# 1601  understand      show       how       1.0
# 3070     analyze     theme      them       1.0
# Emily evaporated a solution and drew a picture of the crystals that remained. Using the crystal-shape key below, what was dissolved in the solution? A. Epsom salt (B. alum) C. sodium thiosulfate.  Explain why you chose that answer.
#           domain      verb  question  distance
# 697     remember      what      what       0.0
# 879     remember       why       why       0.0
# 1762  understand   explain   Explain       0.0
# 4992    evaluate   explain   Explain       0.0
# 6768      create  solution  solution       0.0
# 6788      create  solution  solution       0.0
# 201     remember    choose     chose       1.0
# 689     remember      what      that       1.0
# 712     remember      what      that       1.0
# 845     remember       who       why       1.0
# 2513       apply    choose     chose       1.0
# 4587    evaluate    choose     chose       1.0
# 5913      create    choose     chose       1.0
# Salt crystals form when the water evaporates from saltwater. Describe the salt crystals.
#        domain      verb  question  distance
# 276  remember      when      when       0.0
# 347  remember  describe  Describe       0.0
# You can tell if a rock contains calcite by putting it into a cold acid (like vinegar). Describe what you would observe if you did the acid test on a rock that contains this substance.
#         domain      verb  question  distance
# 610   remember      tell      tell       0.0
# 656   remember      what      what       0.0
# 847   remember  describe  Describe       0.0
# 4089  evaluate      test      test       0.0
# 6489    create      test      test       0.0
# 668   remember      what      that       1.0
# Carrie wanted to find out which was harder, a penny or a nickel, so she did a scratch test. How would this tell her which is harder?
#           domain   verb question  distance
# 171     remember   find     find       0.0
# 208     remember    how      How       0.0
# 475     remember   tell     tell       0.0
# 557     remember  which    which       0.0
# 573     remember  which    which       0.0
# 2211     analyze   find     find       0.0
# 3063    evaluate   test     test       0.0
# 4863      create   test     test       0.0
# 424     remember   show      How       1.0
# 1552  understand   show      How       1.0
# The sand and flour in the gray material from mock rocks is separated by mixing with water and allowing the mixture to settle. Explain why the sand and flour separate.
#           domain     verb question  distance
# 774     remember      why      why       0.0
# 1553  understand  explain  Explain       0.0
# 4403    evaluate  explain  Explain       0.0
# 744     remember      who      why       1.0
# Anna wants to compare the fat in walnuts and peanuts, but she isn't sure how. Write a procedure Anna can use to compare the fat in walnuts and peanuts.
#           domain     verb question  distance
# 238     remember      how      how       0.0
# 1319  understand  compare  compare       0.0
# 1337  understand  compare  compare       0.0
# 1515  understand  compare  compare       0.0
# 1533  understand  compare  compare       0.0
# 1979       apply      use      use       0.0
# 2915     analyze  compare  compare       0.0
# 2933     analyze  compare  compare       0.0
# 3783    evaluate  compare  compare       0.0
# 3801    evaluate  compare  compare       0.0
# 490     remember     show      how       1.0
# 1806  understand     show      how       1.0
# Anna wants to compare the fat in walnuts and peanuts. Using only the results from her experiment, how will Anna know which one, walnuts or peanuts, has more fat? The experiment has the following procedure: Measure out equal masses of walnuts and peanuts (for example, one gram). Smash the samples uniformly in the same size area on brown paper. Wait (the same time for each).
#           domain     verb question  distance
# 537     remember      how      how       0.0
# 1516    remember    which    which       0.0
# 3058  understand  compare  compare       0.0
# 3513  understand  compare  compare       0.0
# 6763     analyze  compare  compare       0.0
# 8778    evaluate  compare  compare       0.0
# 9980    evaluate  measure  Measure       0.0
# 833     remember     name     same       1.0
# 841     remember     name     same       1.0
# 1122    remember     show      how       1.0
# 4177  understand     show      how       1.0
# Susan has samples of 5 different foods. Using only the results of her experiment, how will Susan know which food contains the most sugar?
#           domain   verb question  distance
# 197     remember    how      how       0.0
# 546     remember  which    which       0.0
# 404     remember   show      how       1.0
# 1485  understand   show      how       1.0
# Diva's father told her she should not eat so many cookies because they were pure sugar. Diva decided to investigate the amount of sugar in Fruity Cream cookies. She performed the sugar test on 4 grams of pure sugar and on 4 grams of Fruity Cream cookies. The results are pictured at the right. Are Fruity Cream cookies pure sugar? What is your evidence?
#          domain    verb question  distance
# 1298   remember    what     What       0.0
# 7906   evaluate    test     test       0.0
# 12556    create    test     test       0.0
# 1377   remember   where     were       1.0
# 8635   evaluate  decide  decided       1.0
# Diva's father told her she should not eat so many cookies because they were pure sugar. Diva decided to investigate the amount of sugar in Fruity Cream cookies. She performed the sugar test on 4 grams of pure sugar and on 4 grams of Fruity Cream cookies. The results are pictured at the right. Why did Diva need to test pure sugar?
#          domain    verb question  distance
# 1552   remember     why      Why       0.0
# 7652   evaluate    test     test       0.0
# 7677   evaluate    test     test       0.0
# 12152    create    test     test       0.0
# 12177    create    test     test       0.0
# 1333   remember   where     were       1.0
# 1492   remember     who      Why       1.0
# 8357   evaluate  decide  decided       1.0
# Paula wants to test a food to see if it contains acid and/or sugar. When Paula added water and yeast to a sample of the food and put the mixture in a warm water bath, the mixture began to fizz and bubble. What does this chemical reaction indicate?
#         domain  verb question  distance
# 960   remember  what     What       0.0
# 980   remember  when     When       0.0
# 5845  evaluate  test     test       0.0
# 9295    create  test     test       0.0
# Paula wants to test a food to see if it contains acid and/or sugar. When Paula added water and yeast to a sample of the food and put the mixture in a warm water bath, the mixture began to fizz and bubble. Paula tested for the other substance. What would the test results tell her?
#          domain  verb question  distance
# 1058   remember  tell     tell       0.0
# 1106   remember  what     What       0.0
# 1127   remember  when     When       0.0
# 6734   evaluate  test     test       0.0
# 6780   evaluate  test     test       0.0
# 10709    create  test     test       0.0
# 10755    create  test     test       0.0
# Jana and Emily used indophenol to test 3 beverages for vitamin C. The number of drops they added to make a 10 milliliter sample of the blue indophenol indicator become colorless are given here: 8 drops of Overly Orange 13 drops of Luscious Lemon 33 drops of Fruitsnap (and it still didn't change color). Does Overly Orange or Luscious Lemon contain a higher concentration of vitamin C? What is the evidence?
#          domain    verb question  distance
# 1361   remember    what     What       0.0
# 8261   evaluate    test     test       0.0
# 11228    create  change   change       0.0
# 13136    create    test     test       0.0
# 1460   remember   where     here       1.0
# 4553      apply     use     used       1.0
# Jana and Emily used indophenol to test 3 beverages for vitamin C. The number of drops they added to make a 10 milliliters sample of the blue indophenol indicator become colorless are given here: 8 drops of Overly Orange 13 drops of Luscious Lemon 33 drops of Fruitsnap (and it still didn't change color). Why didn't the indophenol change color with Fruitsnap?
#          domain    verb question  distance
# 1500   remember     why      Why       0.0
# 7372   evaluate    test     test       0.0
# 10024    create  change   change       0.0
# 10030    create  change   change       0.0
# 11722    create    test     test       0.0
# 1306   remember   where     here       1.0
# 1442   remember     who      Why       1.0
# 4063      apply     use     used       1.0
# Look at the finger patterns below, then answer the questions. What is the same about the finger patterns?
#        domain  verb question  distance
# 370  remember  what     What       0.0
# 229  remember  name     same       1.0
# 384  remember  when     then       1.0
# Look at the rubbings of 2 different fabrics. What do the rubbings tell us about the different textures of these 2 fabrics?
#         domain   verb question  distance
# 391   remember   tell     tell       0.0
# 407   remember   what     What       0.0
# 1412     apply    use       us       1.0
# 2458   analyze  theme    these       1.0
# Look at the finger patterns below, then answer the questions. What is different about the finger patterns?
#        domain  verb question  distance
# 350  remember  what     What       0.0
# 363  remember  when     then       1.0
# Design a way to use carbon printing to find out if 2 Labrador retrievers have the same paw patterns. How will you know if the 2 dogs have paw patterns that are the same?
#           domain    verb question  distance
# 224     remember    find     find       0.0
# 265     remember     how      How       0.0
# 2173       apply     use      use       0.0
# 2859     analyze    find     find       0.0
# 5177      create  design   Design       0.0
# 5580      create  design   Design       0.0
# 386     remember    name     same       1.0
# 402     remember    name     same       1.0
# 544     remember    show      How       1.0
# 647     remember    what     that       1.0
# 776     remember     why      way       1.0
# 2001  understand    show      How       1.0
# When Sarah did the chromatography test, she saw that one black ink stayed black and didn't separate. She discovered that she had used a permanent marker. She wondered what would happen if she used a different liquid. She wrote in her science notebook, What if I used vinegar in place of the water? Can I get the pigments in permanent ink to separate? How will Sarah know if vinegar separated the permanent ink?
#            domain    verb question  distance
# 611      remember     how      How       0.0
# 1407     remember    what     what       0.0
# 1421     remember    what     What       0.0
# 1449     remember    when     When       0.0
# 8768     evaluate    test     test       0.0
# 12863      create  happen   happen       0.0
# 13943      create    test     test       0.0
# 1232     remember    show      How       1.0
# 1388     remember    what     that       1.0
# 1399     remember    what     that       1.0
# 4475   understand    show      How       1.0
# 4852        apply     use     used       1.0
# 4862        apply     use     used       1.0
# 4873        apply     use     used       1.0
# Describe what you would see if a mirror were placed along a line of symmetry on a flat object.
#        domain      verb  question  distance
# 321  remember      what      what       0.0
# 416  remember  describe  Describe       0.0
# 359  remember     where      were       1.0
# Don wants to make a map of his neighborhood that fits into his notebook. He has a photograph of the neighborhood but it is too large. Complete the description of how Don can draw an accurate map that fits into his notebook: 1. Put an overlay grid over the model. 2. ____ 3. Draw a smaller grid with the same number of squares in your notebook. 4. ____ 5. Create a key to go with the map.
#            domain    verb question  distance
# 572      remember     how      how       0.0
# 3336   understand     map      map       0.0
# 3366   understand     map      map       0.0
# 3399   understand     map      map       0.0
# 5486        apply   model    model       0.0
# 12165      create  create   Create       0.0
# 869      remember    name     same       1.0
# 1184     remember    show      how       1.0
# 1368     remember    what     that       1.0
# 1395     remember    what     that       1.0
# 4380   understand    show      how       1.0
# What process forms deltas? A. Gravity B. Erosion (C. Deposition) D. Decomposition.  Explain how deltas form.
#           domain     verb question  distance
# 105     remember      how      how       0.0
# 240     remember     what     What       0.0
# 620   understand  explain  Explain       0.0
# 1760    evaluate  explain  Explain       0.0
# 213     remember     show      how       1.0
# 777   understand     show      how       1.0
# Below is a drawing of a river that carried sand, clay, and pebbles (past the river's mouth) to a lake. Why is the clay deposited where you indicated?
#        domain   verb question  distance
# 572  remember  where    where       0.0
# 642  remember    why      Why       0.0
# 505  remember   what     that       1.0
# 617  remember    who      Why       1.0
# Draw an arrow to show which direction the water flows in the river. (Rose Mountain is on the left and Happy Valley is on the right in the drawing.) Why do you think the water flows in that direction?
#           domain   verb question  distance
# 667     remember   show     show       0.0
# 902     remember  which    which       0.0
# 1004    remember    why      Why       0.0
# 2500  understand   show     show       0.0
# 316     remember    how     show       1.0
# 817     remember   what     that       1.0
# 965     remember    who      Why       1.0
# How does the water flow in a creek during a flood compared to normal water flow?
#           domain     verb  question  distance
# 112     remember      how       How       0.0
# 238     remember     show       How       1.0
# 667   understand  compare  compared       1.0
# 765   understand  compare  compared       1.0
# 896   understand     show       How       1.0
# 1465     analyze  compare  compared       1.0
# 1899    evaluate  compare  compared       1.0
# Use the "slope" and "no slope" stream-table maps and logs on the facing page to answer these questions. What information do you get from the stream-table logs that you do not get from the stream-table maps?
#           domain   verb question  distance
# 799     remember   what     What       0.0
# 2730       apply    use      Use       0.0
# 809     remember   what     that       1.0
# 1919  understand    map     maps       1.0
# 1949  understand    map     maps       1.0
# 4775     analyze  theme    these       1.0
# Pam and her family were planning a hike. Pam found 2 maps of the same area. Her friend recommended she use the topographic map when they went to the lake. Why would Pam's friend recommend using the topographic map for the hike?
#           domain       verb   question  distance
# 862     remember       when       when       0.0
# 1028    remember        why        Why       0.0
# 1981  understand        map        map       0.0
# 1996  understand        map        map       0.0
# 2818       apply        use        use       0.0
# 6392    evaluate  recommend  recommend       0.0
# 492     remember       name       same       1.0
# 884     remember      where       were       1.0
# 988     remember        who        Why       1.0
# 1969  understand        map       maps       1.0
# Pam and her family were planning a hike. Pam found 2 maps of the same area. Her friend recommended she use the topographic map when they went to the lake. Which letter (Q, R, or S) on the map is on the steepest part of the trail? (Q) How do you know it is the steepest part of the trail?
#           domain   verb question  distance
# 474     remember    how      How       0.0
# 1156    remember   when     when       0.0
# 1270    remember  which    Which       0.0
# 2667  understand    map      map       0.0
# 2679  understand    map      map       0.0
# 3798       apply    use      use       0.0
# 660     remember   name     same       1.0
# 960     remember   show      How       1.0
# 1192    remember  where     were       1.0
# 2655  understand    map     maps       1.0
# 3498  understand   show      How       1.0
# What happens to earth materials during deposition?
#         domain    verb question  distance
# 140   remember    what     What       0.0
# 1303    create  happen  happens       1.0
# The change in elevation between contour line A and contour line B is 20 meters. What is the change in elevation between contour line A and contour line C? How do you know that is the change in elevation between A and C?
#           domain    verb question  distance
# 321     remember     how      How       0.0
# 753     remember    what     What       0.0
# 6365      create  change   change       0.0
# 6380      create  change   change       0.0
# 6396      create  change   change       0.0
# 654     remember    show      How       1.0
# 769     remember    what     that       1.0
# 2393  understand    show      How       1.0
# Mark an X next to each of the following that can cause more erosion in a streamtable experiment. (Use a water source with a bigger hole.) Use a water source with a smaller hole.  Make the slope flatter. (Make the slope steeper.) Explain why your choices cause more erosion.
#           domain     verb question  distance
# 1112    remember      why      why       0.0
# 2229  understand  explain  Explain       0.0
# 3026       apply      use      Use       0.0
# 3032       apply      use      Use       0.0
# 6314    evaluate  explain  Explain       0.0
# 6536    evaluate     mark     Mark       0.0
# 868     remember     what     that       1.0
# 1069    remember      who      why       1.0
# What is the relationship between the amount of effort required to lift the load and its distance from the fulcrum?
#         domain  verb question  distance
# 400   remember  what     What       0.0
# 211   remember  list     lift       1.0
# 2311   analyze  list     lift       1.0
# Look at the illustration of the pulley system at the right to answer the questions. What additional disadvantages might there be to this system compared to a single fixed pulley system?
#           domain     verb  question  distance
# 615     remember     what      What       0.0
# 679     remember    where     there       1.0
# 1434  understand  compare  compared       1.0
# 1644  understand  compare  compared       1.0
# 3144     analyze  compare  compared       1.0
# 3679     analyze    theme     there       1.0
# 4074    evaluate  compare  compared       1.0
# How can you use a magnet to find out if the key is iron or aluminum?
#           domain  verb question  distance
# 111     remember  find     find       0.0
# 120     remember   how      How       0.0
# 1053       apply   use      use       0.0
# 1386     analyze  find     find       0.0
# 255     remember  show      How       1.0
# 960   understand  show      How       1.0
# Look at the picture on the right. Label the poles on each magnet. (The bottom 2 magnets are stuck together, the others are not.) What is the rule that explains why you labeled the poles the way you did?
#           domain     verb  question  distance
# 349     remember    label     Label       0.0
# 783     remember     what      What       0.0
# 979     remember      why       why       0.0
# 787     remember     what      that       1.0
# 941     remember      who       why       1.0
# 985     remember      why       way       1.0
# 1966  understand  explain  explains       1.0
# 5576    evaluate  explain  explains       1.0
# Sometimes a red stoplight changes to green only when a car stops at the light. A type of magnet hidden under the surface of the road triggers the light to turn green. What is it about the car that could trigger a magnet to send a signal to the light?
#         domain    verb question  distance
# 929   remember    what     What       0.0
# 952   remember    when     when       0.0
# 935   remember    what     that       1.0
# 7743    create  change  changes       1.0
# Anne is investigating which objects stick to magnets. She recorded this in her notebook. I was surprised! A nail was stuck to the magnet. When I accidentally touched the nail to a paperclip, the paperclip stuck to the nail. If Anne touched the nail to a brass ring, what do you think would happen and why?
#         domain    verb question  distance
# 1063  remember    what     what       0.0
# 1093  remember    when     When       0.0
# 1176  remember   which    which       0.0
# 1325  remember     why      why       0.0
# 9534    create  happen   happen       0.0
# 1274  remember     who      why       1.0
# Look at the circuit in the picture. The gap between the D-cell and the switch needs to be connected. Can you use a piece of string to make the connection? Why or why not?
#           domain  verb question  distance
# 854     remember   why      Why       0.0
# 856     remember   why      why       0.0
# 2331       apply   use      use       0.0
# 638     remember  tell     cell       1.0
# 821     remember   who      Why       1.0
# 823     remember   who      why       1.0
# 1625  understand   map      gap       1.0
# Look at the circuit in the picture. The gap between the D-cell and the switch needs to be connected. Can you use a piece of aluminum foil to make the connection? Why or why not?
#           domain  verb question  distance
# 880     remember   why      Why       0.0
# 882     remember   why      why       0.0
# 2401       apply   use      use       0.0
# 657     remember  tell     cell       1.0
# 846     remember   who      Why       1.0
# 848     remember   who      why       1.0
# 1674  understand   map      gap       1.0
# Look at the diagram of a circuit at the right. Will the motor run? Why?
#        domain verb question  distance
# 363  remember  why      Why       0.0
# 349  remember  who      Why       1.0
# Only one circuit below will light the bulb. Which one will work? Why is that the only circuit that will work?
#        domain   verb question  distance
# 491  remember  which    Which       0.0
# 537  remember    why      Why       0.0
# 434  remember   what     that       1.0
# 438  remember   what     that       1.0
# 516  remember    who      Why       1.0
# Lee has an object he wants to test to see if it is an insulator or a conductor. He is going to use the circuit you see in the picture. Explain how he can use the circuit to test the object.
#           domain     verb question  distance
# 350     remember      how      how       0.0
# 2069  understand  explain  Explain       0.0
# 2821       apply      use      use       0.0
# 2833       apply      use      use       0.0
# 5087    evaluate     test     test       0.0
# 5117    evaluate     test     test       0.0
# 5869    evaluate  explain  Explain       0.0
# 8087      create     test     test       0.0
# 8117      create     test     test       0.0
# 710     remember     show      how       1.0
# 2590  understand     show      how       1.0
# Lee has an object he wants to test to see if it is an insulator or a conductor. He is going to use the circuit you see in the picture. How will he know if the object is a conductor?
#           domain  verb question  distance
# 333     remember   how      How       0.0
# 2681       apply   use      use       0.0
# 4833    evaluate  test     test       0.0
# 7683      create  test     test       0.0
# 675     remember  show      How       1.0
# 2461  understand  show      How       1.0
# Denise made a circuit to light a bulb or run a motor. She used a special switch. Below is the schematic diagram of her circuit. The switch is inside the dotted box. What will happen when she moves the switch to the left?
#         domain    verb question  distance
# 808   remember    what     What       0.0
# 850   remember    when     when       0.0
# 7284    create  happen   happen       0.0
# 2740     apply     use     used       1.0
# Denise made a circuit to light a bulb or run a motor off a D-cell battery. She used a special switch. Below is the schematic diagram of her circuit. The switch is inside the dotted box. Why will the bulb light when she moves the switch to the left?
#         domain  verb question  distance
# 960   remember  when     when       0.0
# 1131  remember   why      Why       0.0
# 846   remember  tell     cell       1.0
# 1087  remember   who      Why       1.0
# 3093     apply   use     used       1.0
# Denise made a circuit to light a bulb or run a motor. She used a special switch. Below is the schematic diagram of her circuit. The switch is inside the dotted box. What will happen when she moves the switch to the right?
#         domain    verb question  distance
# 808   remember    what     What       0.0
# 850   remember    when     when       0.0
# 7284    create  happen   happen       0.0
# 2740     apply     use     used       1.0
#  Denise made a circuit to light a bulb or run a motor off a D-cell battery. She used a special switch. Below is the schematic diagram of her circuit. The switch is inside the dotted box. Why will the motor run when she moves the switch to the right?
#         domain  verb question  distance
# 960   remember  when     when       0.0
# 1131  remember   why      Why       0.0
# 846   remember  tell     cell       1.0
# 1087  remember   who      Why       1.0
# 3093     apply   use     used       1.0
# Denise made a circuit to light a bulb or run a motor. She used a special switch. Below is the schematic diagram of her circuit. The switch is inside the dotted box. Can she run both the light and the motor at the same time? Why or why not?
#         domain  verb question  distance
# 1166  remember   why      Why       0.0
# 1168  remember   why      why       0.0
# 579   remember  name     same       1.0
# 1121  remember   who      Why       1.0
# 1123  remember   who      why       1.0
# 3160     apply   use     used       1.0
# Trace over the complete circuit with your pencil to show where it is. Even though there is a complete circuit, the bulb will not light. Why not?
#           domain   verb question  distance
# 451     remember   show     show       0.0
# 582     remember  where    where       0.0
# 674     remember    why      Why       0.0
# 1673  understand   show     show       0.0
# 217     remember    how     show       1.0
# 587     remember  where    there       1.0
# 648     remember    who      Why       1.0
# 3187     analyze  theme    there       1.0
# The motors shown at the right with the D-cell batteries will NOT run. Explain why.
#           domain     verb question  distance
# 389     remember      why      why       0.0
# 778   understand  explain  Explain       0.0
# 2203    evaluate  explain  Explain       0.0
# 257     remember     show    shown       1.0
# 293     remember     tell     cell       1.0
# 374     remember      who      why       1.0
# 962   understand     show    shown       1.0
# Look at the picture of the circuit to the right. What will happen to the motor if the light bulb burns out?
#         domain    verb question  distance
# 450   remember    what     What       0.0
# 4104    create  happen   happen       0.0
# Kurt was investigating which objects stick to magnets. He made an entry in his science notebook and drew a picture to help explain what he did. Look what I did! I picked up a paperclip with a magnet. Then that paperclip picked up another one, and then another one. And they weren't hooked together either. All they had to do was touch each other. Explain to Kurt why he was able to pick up all those paperclips, even though the magnet was only touching the first one.
#            domain     verb question  distance
# 1662     remember     what     what       0.0
# 1666     remember     what     what       0.0
# 1889     remember    which    which       0.0
# 2112     remember      why      why       0.0
# 4203   understand  explain  explain       0.0
# 4241   understand  explain  Explain       0.0
# 11993    evaluate  explain  explain       0.0
# 12031    evaluate  explain  Explain       0.0
# 1674     remember     what     that       1.0
# 1755     remember     when     Then       1.0
# 1763     remember     when     then       1.0
# 2030     remember      who      why       1.0
# Look at the schematic diagram. What will happen to the other 2 bulbs if the middle bulb burns out?
#         domain    verb question  distance
# 365   remember    what     What       0.0
# 3355    create  happen   happen       0.0
# Look at the schematic diagram including a D-cell battery and 3 bulbs. Why do the other 2 bulbs stay lit if the middle bulb burns out?
#         domain  verb question  distance
# 585   remember   why      Why       0.0
# 246   remember  list      lit       1.0
# 443   remember  tell     cell       1.0
# 562   remember   who      Why       1.0
# 2661   analyze  list      lit       1.0
# A magnet attracted another magnet even when a foam block was placed between them (see box A below). What do you think would happen if 2 foam blocks were placed between the 2 magnets (see box B). A. The magnets will stick. B. The magnets will not stick. (C. It might stick, but it might not.) Explain why you chose that answer.
#           domain     verb question  distance
# 1075    remember     what     What       0.0
# 1118    remember     when     when       0.0
# 1373    remember      why      why       0.0
# 2750  understand  explain  Explain       0.0
# 7785    evaluate  explain  Explain       0.0
# 9878      create   happen   happen       0.0
# 315     remember   choose    chose       1.0
# 1111    remember     what     that       1.0
# 1190    remember    where     were       1.0
# 1320    remember      who      why       1.0
# 3919       apply   choose    chose       1.0
# 6477     analyze    theme     them       1.0
# 7152    evaluate   choose    chose       1.0
# 9219      create   choose    chose       1.0
# Wendy is making an electromagnet. She wrapped a long, insulated wire around an iron nail. What should Wendy do next to complete the electromagnet?
#        domain  verb question  distance
# 474  remember  what     What       0.0
# Greta used her hand to measure the length of the whiteboard in her classroom. She found that it was 14 hands long. Andre measured the whiteboard and found that it was 16 hands long. Explain why Greta and Andre got different measurements.
#           domain     verb  question  distance
# 1085    remember      why       why       0.0
# 2176  understand  explain   Explain       0.0
# 6166    evaluate  explain   Explain       0.0
# 6431    evaluate  measure   measure       0.0
# 856     remember     what      that       1.0
# 868     remember     what      that       1.0
# 1043    remember      who       why       1.0
# 2941       apply      use      used       1.0
# 6449    evaluate  measure  measured       1.0
# 2 groups used marbles to weigh the same apple. Jin's group found the apple weighed 35 marbles and Bee's group found the same apple weighed 60 marbles. Both groups used the correct procedure. Since they weighed the same apple, what do you think happened to make the results different?
#         domain   verb question  distance
# 998   remember   what     what       0.0
# 582   remember   name     same       1.0
# 597   remember   name     same       1.0
# 612   remember   name     same       1.0
# 3361     apply    use     used       1.0
# 3388     apply    use     used       1.0
# 3415     apply  apply    apple       1.0
# 3420     apply  apply    apple       1.0
# 3430     apply  apply    apple       1.0
# 3445     apply  apply    apple       1.0
# 2 groups used marbles to weigh the same apple. Jin's group found the apple weighed 35 marbles and Bee's group found the same apple weighed 60 marbles. Both groups used the correct procedure. What should the groups do to make their results more useful?
#         domain   verb question  distance
# 892   remember   what     What       0.0
# 522   remember   name     same       1.0
# 537   remember   name     same       1.0
# 3011     apply    use     used       1.0
# 3038     apply    use     used       1.0
# 3060     apply  apply    apple       1.0
# 3065     apply  apply    apple       1.0
# 3075     apply  apply    apple       1.0
# Why is it important to use a standard unit when making a measurement?
#        domain  verb question  distance
# 239  remember  when     when       0.0
# 275  remember   why      Why       0.0
# 775     apply   use      use       0.0
# 264  remember   who      Why       1.0
# Jen was talking on the phone with her Uncle Bill who lives in Canada. When she asked him how the weather was, he said it was nice and warm, about 28 degrees. What unit is Uncle Bill using to report the temperature?
#           domain  verb question  distance
# 354     remember   how      how       0.0
# 872     remember  what     What       0.0
# 896     remember  when     When       0.0
# 1018    remember   who      who       0.0
# 732     remember  show      how       1.0
# 1060    remember   why      who       1.0
# 2706  understand  show      how       1.0
# Look at the picture below [which shows a balance tipped down on the side containing a ball; the right cup has 20 grams and 10 grams mass pieces]. The mass of the ball is one of the following. It must be A. 20 grams. B. 30 grams. (C. 40 grams.) Explain why you chose the answer that you did.
#           domain     verb question  distance
# 1247    remember    which    which       0.0
# 1396    remember      why      why       0.0
# 2799  understand  explain  Explain       0.0
# 7929    evaluate  explain  Explain       0.0
# 318     remember   choose    chose       1.0
# 924     remember     show    shows       1.0
# 1131    remember     what     that       1.0
# 1342    remember      who      why       1.0
# 3462  understand     show    shows       1.0
# 3990       apply   choose    chose       1.0
# 7284    evaluate   choose    chose       1.0
# 9390      create   choose    chose       1.0
# Mary told her friend Sharice that she had a rug to sell. Sharice asked if the rug would fit perfectly, wall to wall, in her bedroom. Mary went home and measured the rug. She put her feet heel-to-toe and counted the number of shoe lengths it took to measure the rug. She found the rug was 18 shoes long and 12 shoes wide. Sharice did the same thing in her room to measure the space for the rug. Her floor was 18 shoes long and 12 shoes wide. A perfect fit! Sharice bought the rug and took it home. To her dismay, she found it was too short and too narrow for her bedroom! What could Mary and Sharice do to better measure the size of the rug?
#            domain     verb  question  distance
# 2674     remember     what      What       0.0
# 19633    evaluate  measure   measure       0.0
# 19657    evaluate  measure   measure       0.0
# 19706    evaluate  measure   measure       0.0
# 1603     remember     name      same       1.0
# 2220     remember     show      shoe       1.0
# 2314     remember    spell      sell       1.0
# 2442     remember     tell      sell       1.0
# 2565     remember     what      that       1.0
# 8236   understand     show      shoe       1.0
# 19456    evaluate     mark      Mary       1.0
# 19481    evaluate     mark      Mary       1.0
# 19572    evaluate     mark      Mary       1.0
# 19613    evaluate  measure  measured       1.0
# Gerry used a paper filter to separate a mixture of sand, salt, and water. Think about particle size and answer this question: Why did the salt go through the filter while the sand got caught?
#         domain verb question  distance
# 845   remember  why      Why       0.0
# 812   remember  who      Why       1.0
# 2311     apply  use     used       1.0
# A solution is a type of mixture. What makes it different from other mixtures?
#         domain      verb  question  distance
# 245   remember      what      What       0.0
# 2388    create  solution  solution       0.0
# How do you know when a solid and a liquid form a solution?
#           domain      verb  question  distance
# 80      remember       how       How       0.0
# 214     remember      when      when       0.0
# 1999      create  solution  solution       0.0
# 170     remember      show       How       1.0
# 640   understand      show       How       1.0
# Emily put 20 milliliters of a mystery solution in an evaporation dish. When all the water was gone, she drew the picture of the dish you see here.  Using the crystal-shape key below, what chemical do you think was dissolved in the solution? A. Epsom salt B. Sodium thiosulfate (C. Alum) D. None of the above. Explain why you chose that answer.
#            domain      verb  question  distance
# 1193     remember      what      what       0.0
# 1229     remember      when      When       0.0
# 1503     remember       why       why       0.0
# 3010   understand   explain   Explain       0.0
# 8520     evaluate   explain   Explain       0.0
# 11548      create  solution  solution       0.0
# 11584      create  solution  solution       0.0
# 345      remember    choose     chose       1.0
# 1216     remember      what      that       1.0
# 1302     remember     where      here       1.0
# 1445     remember       who       why       1.0
# 4289        apply    choose     chose       1.0
# 7827     evaluate    choose     chose       1.0
# 10089      create    choose     chose       1.0
# Joanne mixed material R and material D together, added water, and stirred. After a few minutes, the liquid was clear and there was a solid on the bottom of the cup. Joanne used a paper filter to separate the solid from the liquid. Why does the solid stay in the filter when the liquid goes through?
#         domain   verb question  distance
# 1117  remember   when     when       0.0
# 1313  remember    why      Why       0.0
# 1140  remember  where    there       1.0
# 1262  remember    who      Why       1.0
# 3598     apply    use     used       1.0
# 6240   analyze  theme    there       1.0
# Mariella made a saturated solution by adding a solid to 100 milliliters water. Richard made a saturated solution by adding the same solid to 250 milliliters water. Do the 2 saturated solutions have the same concentration? Explain your answer.
#           domain      verb   question  distance
# 1817  understand   explain    Explain       0.0
# 5142    evaluate   explain    Explain       0.0
# 6968      create  solution   solution       0.0
# 6979      create  solution   solution       0.0
# 438     remember      name       same       1.0
# 450     remember      name       same       1.0
# 6992      create  solution  solutions       1.0
# Nigel made solutions in the bottles as shown below. Solution A was 2 spoons solute in 50 milliliters water and was clear with no material on the bottom. Solution B was 4 spoons solute in 100 milliliters water and was clear with no material on the bottom. Nigel took 50 milliliters of solution from bottle A and put it in cup A and 50 milliliters of solution from bottle B and put it into cup B. He put the cups on each side of the balance. Which picture shows what would happen? A is heavier than B, B is heavier than A, (A and B are the same weight). Explain your choice.
#            domain      verb   question  distance
# 2041     remember      what       what       0.0
# 2332     remember     which      Which       0.0
# 5093   understand   explain    Explain       0.0
# 14403    evaluate   explain    Explain       0.0
# 18311      create    happen     happen       0.0
# 19511      create  solution   Solution       0.0
# 19528      create  solution   Solution       0.0
# 19550      create  solution   solution       0.0
# 19562      create  solution   solution       0.0
# 1269     remember      name       same       1.0
# 1673     remember      show      shown       1.0
# 1746     remember      show      shows       1.0
# 6279   understand      show      shown       1.0
# 6352   understand      show      shows       1.0
# 19504      create  solution  solutions       1.0
# Tabby made 2 solutions using the same solute and water. [Cup one has 6 spoons solute in 50 milliliters water. Cup 2 has 8 spoons solute in 50 milliliters water. Both solutions are clear with material on the bottom.] Which sentence below describes the concentrations of the 2 solutions? (A. The solutions in the cups have the same concentration.) B. Cup one has the more concentrated solution. C. Cup 2 has the more concentrated solution. D. There is not enough information to answer the question. Explain your choice.
#            domain      verb   question  distance
# 1829     remember     which      Which       0.0
# 4053   understand   explain    Explain       0.0
# 11463    evaluate   explain    Explain       0.0
# 15581      create  solution   solution       0.0
# 15587      create  solution   solution       0.0
# 941      remember      name       same       1.0
# 987      remember      name       same       1.0
# 1782     remember     where      There       1.0
# 2066     remember  describe  describes       1.0
# 9582      analyze     theme      There       1.0
# 15524      create  solution  solutions       1.0
# 15549      create  solution  solutions       1.0
# 15565      create  solution  solutions       1.0
# 15567      create  solution  solutions       1.0
# Jorge added solid material to a container of clear colorless liquid. The mixture began to bubble. Explain why Jorge knew a chemical reaction occurred.
#           domain     verb question  distance
# 566     remember      why      why       0.0
# 1137  understand  explain  Explain       0.0
# 3227    evaluate  explain  Explain       0.0
# 544     remember      who      why       1.0
# A solution of water and material A is clear. A solution of water and material B is also clear. When the 2 solutions are mixed, a white solid settles to the bottom, leaving a clear liquid. What does the white solid indicate?
#         domain      verb   question  distance
# 729   remember      what       What       0.0
# 750   remember      when       When       0.0
# 6965    create  solution   solution       0.0
# 6972    create  solution   solution       0.0
# 6982    create  solution  solutions       1.0
# When Amy added water to a mixture of baking soda and citric acid, the mixture began fizzing. Amy concluded there was a chemical reaction because it fizzed. Why is fizzing evidence of a chemical reaction?
#           domain      verb   question  distance
# 672     remember      when       When       0.0
# 825     remember       why        Why       0.0
# 722     remember     where      there       1.0
# 793     remember       who        Why       1.0
# 1393  understand  conclude  concluded       1.0
# 3922     analyze     theme      there       1.0
# 4369    evaluate  conclude  concluded       1.0
# Grace set up a science experiment. Here's what she wrote in her notebook. First I put eggshells into a cup and covered them with vinegar. After a while, small bubbles appeared on the surface of the eggshells. The next day there were more bubbles. In a couple of days, the eggshells were gone and the liquid was clear. I think I made a solution and a reaction. Explain why Grace thinks she made a solution.
#            domain      verb  question  distance
# 1306     remember      what      what       0.0
# 1684     remember       why       why       0.0
# 3373   understand   explain   Explain       0.0
# 9548     evaluate   explain   Explain       0.0
# 12990      create  solution  solution       0.0
# 12999      create  solution  solution       0.0
# 1435     remember     where      Here       1.0
# 1466     remember     where     there       1.0
# 1467     remember     where      were       1.0
# 1476     remember     where      were       1.0
# 1619     remember       who       why       1.0
# 7949      analyze     theme      them       1.0
# 7966      analyze     theme     there       1.0
# Grace set up a science experiment. Here's what she wrote in her notebook. First I put eggshells into a cup and covered them with vinegar. After a while, small bubbles appeared on the surface of the eggshells. The next day there were more bubbles. In a couple of days, the eggshells were gone and the liquid was clear. I think I made a solution and a reaction. Explain why Grace thinks she made a reaction.
#            domain      verb  question  distance
# 1306     remember      what      what       0.0
# 1684     remember       why       why       0.0
# 3373   understand   explain   Explain       0.0
# 9548     evaluate   explain   Explain       0.0
# 12990      create  solution  solution       0.0
# 1435     remember     where      Here       1.0
# 1466     remember     where     there       1.0
# ...
#           domain      verb  question  distance
# 105     remember  identify  Identify       0.0
# 308     remember       how       how       0.0
# 794     remember      when      when       0.0
# 2880       apply  identify  Identify       0.0
# 5672    evaluate   measure   measure       0.0
# 641     remember      show       how       1.0
# 656     remember      show     shown       1.0
# 836     remember     where      were       1.0
# 2380  understand      show       how       1.0
# 2395  understand      show     shown       1.0
# 5152    evaluate    decide   decided       1.0
# Explain in one sentence what each graph tells you. Graph A) number of tree rings versus time.
#           domain     verb question  distance
# 324     remember     what     what       0.0
# 816   understand  explain  Explain       0.0
# 2336    evaluate  explain  Explain       0.0
# 311     remember     tell    tells       1.0
# Explain in one sentence what each graph tells you. Graph B) speed of light versus time.
#           domain     verb question  distance
# 304     remember     what     what       0.0
# 765   understand  explain  Explain       0.0
# 2190    evaluate  explain  Explain       0.0
# 292     remember     tell    tells       1.0
# Describe what the graph tells you about the relationship between the number of scoops of fertilizer and the mass of beans harvested?
#        domain      verb  question  distance
# 441  remember      what      what       0.0
# 572  remember  describe  Describe       0.0
# 422  remember      tell     tells       1.0
# Don wanted to find out if a battery powered toy truck would always travel the same distance in 10 seconds no matter how heavy a load the truck carried. He placed one or more blocks (the load) in the back of the truck and recorded his results. (Each block had the same mass.) The following graph displays his results. What is the relationship between the number of blocks and the distance traveled by the truck in 10 seconds?
#           domain  verb question  distance
# 535     remember  find     find       0.0
# 629     remember   how      how       0.0
# 1577    remember  what     What       0.0
# 6995     analyze  find     find       0.0
# 926     remember  name     same       1.0
# 961     remember  name     same       1.0
# 1313    remember  show      how       1.0
# 4885  understand  show      how       1.0
# 3 girls wanted to see who could throw a ball the farthest. Each girl brought her favorite ball to the park. Ling brought her basketball, Diana brought her football, and Rachael brought her baseball. They made a line on the playground. They all had to throw the ball from that line. Ling took 2 steps up to the line and threw her basketball. Diana stood at the line and threw her football. Rachael got a running start and threw her baseball when she reached the line. Rachael threw her ball the farthest. What variable did the girls control in the contest?
#          domain  verb question  distance
# 2007   remember  what     What       0.0
# 2092   remember  when     when       0.0
# 2308   remember   who      who       0.0
# 1966   remember  what     that       1.0
# 2404   remember   why      who       1.0
# 14610  evaluate  mark     park       1.0
# 3 girls wanted to see who could throw a ball the farthest. Each girl brought her favorite ball to the park. Ling brought her basketball, Diana brought her football, and Rachael brought her baseball. They made a line on the playground. They all had to throw the ball from that line. Ling took 2 steps up to the line and threw her basketball. Diana stood at the line and threw her football. Rachael got a running start and threw her baseball when she reached the line. Rachael threw her ball the farthest. Describe 2 variables that are not controlled in the contest.
#          domain      verb  question  distance
# 2092   remember      when      when       0.0
# 2308   remember       who       who       0.0
# 2583   remember  describe  Describe       0.0
# 1966   remember      what      that       1.0
# 2009   remember      what      that       1.0
# 2404   remember       why       who       1.0
# 14610  evaluate      mark      park       1.0
# 3 girls wanted to see who could throw a ball the farthest. Each girl brought her favorite ball to the park. Ling brought her basketball, Diana brought her football, and Rachael brought her baseball. They made a line on the playground. They all had to throw the ball from that line. Ling took 2 steps up to the line and threw her basketball. Diana stood at the line and threw her football. Rachael got a running start and threw her baseball when she reached the line. Rachael threw her ball the farthest. Describe what the girls need to do to make the contest a controlled experiment (fair test).
#          domain      verb  question  distance
# 2128   remember      what      what       0.0
# 2218   remember      when      when       0.0
# 2452   remember       who       who       0.0
# 2739   remember  describe  Describe       0.0
# 13055  evaluate      test      test       0.0
# 20705    create      test      test       0.0
# 2086   remember      what      that       1.0
# 2554   remember       why       who       1.0
# 15522  evaluate      mark      park       1.0
# When conducting a controlled experiment, why do you use a standard?
#        domain  verb question  distance
# 189  remember  when     When       0.0
# 229  remember   why      why       0.0
# 637     apply   use      use       0.0
# 220  remember   who      why       1.0
# Explain why you got a voltage reading of 1.5 for terminal 1 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 1.5 for terminal 2 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 0 for terminal 6 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 0 for terminal 1 and terminal 2.
#           domain     verb question  distance
# 276     remember      why      why       0.0
# 561   understand  explain  Explain       0.0
# 1606    evaluate  explain  Explain       0.0
# 265     remember      who      why       1.0
# Explain why you got a voltage reading of 0 for terminal 1 and terminal 4.
#           domain     verb question  distance
# 276     remember      why      why       0.0
# 561   understand  explain  Explain       0.0
# 1606    evaluate  explain  Explain       0.0
# 265     remember      who      why       1.0
# Explain why you got a voltage reading of 1.5 for terminal 1 and terminal 6.
#           domain     verb question  distance
# 276     remember      why      why       0.0
# 561   understand  explain  Explain       0.0
# 1606    evaluate  explain  Explain       0.0
# 265     remember      who      why       1.0
# Why does measuring voltage help you locate a burned out bulb? Try to answer in terms of electrical states, connections and/ or a gap.
#           domain verb question  distance
# 550     remember  why      Why       0.0
# 528     remember  who      Why       1.0
# 1099  understand  map      gap       1.0
# Why do you think the other terminals are being held in a different electrical state than that of the negative terminal?
#        domain  verb question  distance
# 500  remember   why      Why       0.0
# 415  remember  what     that       1.0
# 480  remember   who      Why       1.0
# Why do you think those terminals and the negative battery terminal are in the same state?
#        domain  verb question  distance
# 400  remember   why      Why       0.0
# 206  remember  name     same       1.0
# 384  remember   who      Why       1.0
# As you move the multimeter leads from one bulb terminal to the next, what does it mean when the voltage reading jumps from 0 to 1.5?
#        domain  verb question  distance
# 493  remember  what     what       0.0
# 521  remember  when     when       0.0
# What is voltage?
#       domain  verb question  distance
# 60  remember  what     What       0.0
# What does a voltage reading of 0 tell you about the connection between a bulb terminal and a battery terminal?
#        domain  verb question  distance
# 309  remember  tell     tell       0.0
# 320  remember  what     What       0.0
# What does a voltage reading of 1.5 tell you about the connection between a bulb terminal and a battery terminal?
#        domain  verb question  distance
# 309  remember  tell     tell       0.0
# 320  remember  what     What       0.0
# Explain why you got a voltage reading of 1.5 for terminal 1 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 1.5 for terminal 3 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 0 for terminal 4 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 0 for terminal 5 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Explain why you got a voltage reading of 0 for terminal 6 and the positive terminal.
#           domain     verb question  distance
# 326     remember      why      why       0.0
# 663   understand  explain  Explain       0.0
# 1898    evaluate  explain  Explain       0.0
# 313     remember      who      why       1.0
# Why?
#       domain verb question  distance
# 25  remember  why      Why       0.0
# 24  remember  who      Why       1.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Why didn^t bulbs A and C go out after bulb B burned out?
#        domain verb question  distance
# 250  remember  why      Why       0.0
# 240  remember  who      Why       1.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Why do both bulbs A and B stay on when bulb C is burned out?
#        domain  verb question  distance
# 259  remember  when     when       0.0
# 300  remember   why      Why       0.0
# 288  remember   who      Why       1.0
# Under what circumstances will a damaged/ burned out bulb affect another bulb?
#        domain  verb question  distance
# 221  remember  what     what       0.0
# Why not?
#       domain verb question  distance
# 50  remember  why      Why       0.0
# 48  remember  who      Why       1.0
# Describe the paths in this diagram and explain how those paths account for the results.
#           domain      verb  question  distance
# 128     remember       how       how       0.0
# 390     remember  describe  Describe       0.0
# 772   understand   explain   explain       0.0
# 2197    evaluate   explain   explain       0.0
# 263     remember      show       how       1.0
# 968   understand      show       how       1.0
# Why was bulb A on when switch Y was open and switch Z was closed?
#        domain  verb question  distance
# 256  remember  when     when       0.0
# 300  remember   why      Why       0.0
# 288  remember   who      Why       1.0
# Why was bulb C off when switch Z was open?
#        domain  verb question  distance
# 172  remember  when     when       0.0
# 200  remember   why      Why       0.0
# 192  remember   who      Why       1.0
# What role does the path play in determining whether or not a switch affects a bulb?
#         domain  verb question  distance
# 280   remember  what     What       0.0
# 1153     apply  plan     play       1.0
# 2329    create  plan     play       1.0
# 2749    create  plan     play       1.0
# When switch X was closed and switch Y was open, why was bulb A on?
#        domain  verb question  distance
# 252  remember  when     When       0.0
# 308  remember   why      why       0.0
# 296  remember   who      why       1.0
# When switch X was open and switch Y was closed, why were bulbs B and C on?
#        domain   verb question  distance
# 273  remember   when     When       0.0
# 333  remember    why      why       0.0
# 295  remember  where     were       1.0
# 320  remember    who      why       1.0
# Under what circumstances will a switch affect a bulb?
#        domain  verb question  distance
# 141  remember  what     what       0.0
# What are the conditions that are required to make a bulb light up?
#        domain  verb question  distance
# 240  remember  what     What       0.0
# 244  remember  what     that       1.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Why does a damaged bulb impact a circuit?
#        domain verb question  distance
# 150  remember  why      Why       0.0
# 144  remember  who      Why       1.0
# Explain your reasoning.
#          domain     verb question  distance
# 153  understand  explain  Explain       0.0
# 438    evaluate  explain  Explain       0.0
# Explain why circuit 2 is not a short circuit.
#           domain     verb question  distance
# 176     remember      why      why       0.0
# 357   understand  explain  Explain       0.0
# 1022    evaluate  explain  Explain       0.0
# 169     remember      who      why       1.0
# Explain why circuit 4 is not a short circuit.
#           domain     verb question  distance
# 176     remember      why      why       0.0
# 357   understand  explain  Explain       0.0
# 1022    evaluate  explain  Explain       0.0
# 169     remember      who      why       1.0
# Explain why circuit 5 is a short circuit.
#          domain     verb question  distance
# 151    remember      why      why       0.0
# 306  understand  explain  Explain       0.0
# 876    evaluate  explain  Explain       0.0
# 145    remember      who      why       1.0
# What do you think the red X means?
#        domain  verb question  distance
# 140  remember  what     What       0.0
# Why does an open switch impact a circuit?
#        domain verb question  distance
# 175  remember  why      Why       0.0
# 168  remember  who      Why       1.0

# %%
domain_proposed
# Out:
# ['remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'understand',
#  'remember',
#  'remember',
#  'evaluate',
#  'evaluate',
#  'remember',
#  'remember',
#  'create',
#  'create',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'understand',
#  'remember',
#  'remember',
#  'remember',
#  'create',
#  'remember',
#  'remember',
#  'remember',
#  'analyze',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'evaluate',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'create',
#  'remember',
#  'create',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'apply',
#  'apply',
#  'remember',
#  'remember',
#  'remember',
#  'evaluate',
#  'remember',
#  'create',
#  'remember',
#  'remember',
#  'remember',
#  'create',
#  'create',
#  'create',
#  'remember',
#  'create',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'evaluate',
#  'create',
#  'remember',
#  'remember',
#  'create',
#  'analyze',
#  'analyze',
#  'remember',
#  'analyze',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'evaluate',
#  'evaluate',
#  'evaluate',
#  'remember',
#  'evaluate',
#  'evaluate',
#  'evaluate',
#  'evaluate',
#  'evaluate',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'create',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'evaluate',
#  'remember',
#  'evaluate',
#  'remember',
#  'remember',
#  'remember',
#  'remember',
#  'remember']

# %%
pd.crosstab(np.array(domain_proposed), columns="count")
# Out:
# col_0       count
# row_0
# analyze         4
# apply           2
# create         13
# evaluate       15
# remember      146
# understand      2

# %%
[verb for domain in domain_verbs.keys() for verb in domain_verbs[domain]]
# Out:
# ['Remember',
#  'RECOGNIZe',
#  'identify',
#  'RECALL',
#  'retrieve',
#  'Choose',
#  'Define',
#  'Find',
#  'How',
#  'Label',
#  'List',
#  'Match',
#  'Name',
#  'Omit',
#  'Recall',
#  'Relate',
#  'Select',
#  'Show',
#  'Spell',
#  'Tell',
#  'What',
#  'When',
#  'Where',
#  'Which',
#  'Who',
#  'Why',
#  'describe',
#  'Understand',
#  'INTERPRET',
#  'clarify',
#  'paraphrase',
#  'represent',
#  'translate',
#  'EXEMPLIFY',
#  'illustrate',
#  'instantiate',
#  'CLASSIFY',
#  'categorize',
#  'subsume',
#  'SUMMARIZe',
#  'abstract',
#  'generalize',
#  'INFERR',
#  'conclude',
#  'extrapolate',
#  'interpolate',
#  'predice',
#  'COMPARe',
#  'contrast',
#  'map',
#  'match',
#  'EXPLAIN',
#  'construct models',
#  'Classify',
#  'Compare',
#  'Contrast',
#  'Demonstrate',
#  'Extend',
#  'Illustrate',
#  'Infer',
#  'Interpret',
#  'Outline',
#  'Relate',
#  'Rephrase',
#  'Show',
#  'Summarize',
#  'Translate',
#  'EXECUTe',
#  'carry out',
#  'IMPLEMENT',
#  'use',
#  'Apply',
#  'Build',
#  'Choose',
#  'Construct',
#  'Develop',
#  'Experiment with',
#  'Identify',
#  'Interview',
#  'Make use of',
#  'Model',
#  'Organize',
#  'Plan',
#  'Select',
#  'Solve',
#  'Utilize',
#  'DIFFERENTIATe',
#  'discriminate',
#  'distinguish',
#  'focus',
#  'select',
#  'ORGANIZe',
#  'find',
#  'coherence',
#  'intergrate',
#  'outline',
#  'parse',
#  'structure',
#  'ATTRIBUTe',
#  'deconstruct',
#  'Analyze',
#  'Assume',
#  'Categorize',
#  'Classify',
#  'Compare',
#  'Conclusion',
#  'Contrast',
#  'Discover',
#  'Dissect',
#  'Distinguish',
#  'Divide',
#  'Examine',
#  'Function',
#  'Infere',
#  'Inspect',
#  'List',
#  'Motive',
#  'Relation',
#  'Simplify',
#  'Survey',
#  'Take part in',
#  'Test for',
#  'Theme',
#  'CHECK',
#  'coordinate',
#  'detect',
#  'monitor',
#  'test',
#  'CRITIQUe',
#  'judge',
#  'Agree',
#  'Appraise',
#  'Assess',
#  'Award',
#  'Choose',
#  'Compare',
#  'Conclude',
#  'Criteria',
#  'Criticize',
#  'Decide',
#  'Deduct',
#  'Defend',
#  'Determine',
#  'Disprove',
#  'Estimate',
#  'Evaluate',
#  'Explain',
#  'Importance',
#  'Influence',
#  'Interpret',
#  'Judge',
#  'Justify',
#  'Mark',
#  'Measure',
#  'Opinion',
#  'Perceive',
#  'Prioritize',
#  'Prove',
#  'Rate',
#  'Recommend',
#  'Rule on',
#  'Select',
#  'Support',
#  'Value',
#  'GENERATe',
#  'hypothesize',
#  'PLAN',
#  'design',
#  'PRODUCe',
#  'construct',
#  'Adapt',
#  'Build',
#  'Change',
#  'Choose',
#  'Combine',
#  'Compile',
#  'Compose',
#  'Construct',
#  'Create',
#  'Delete',
#  'Design',
#  'Develop',
#  'Discuss',
#  'Elaborate',
#  'Estimate',
#  'Formulate',
#  'Happen',
#  'Imagine',
#  'Improve',
#  'Invent',
#  'Make up',
#  'Maximize',
#  'Minimize',
#  'Modify',
#  'Original',
#  'Originate',
#  'Plan',
#  'Predict',
#  'Propose',
#  'Solution',
#  'Solve',
#  'Suppose',
#  'Test',
#  'Theory']

# %%
text="Describe the relationship between the length of the string and the number of swings a swinger makes in 15 seconds."

# %%
text_distances=[]
for i,verb in enumerate(domain_verb):
    for tk_quest in tokenize(text):
        text_distances.append([verb[0],verb[1],tk_quest,levenshtein_dist(verb[1],tk_quest)])

# %%
text_distances_df=pd.DataFrame(np.array(text_distances), columns=["domain", "verb", "question", "distance"])
text_distances_df.distance=text_distances_df.distance.astype('float32')

# %%
text_distances_df[text_distances_df.distance<2].sort_values(by=['distance'])
# Out:
#        domain      verb  question  distance
# 494  remember  describe  Describe       0.0

# %%
freqs=pd.crosstab(distances_df[distances_df.distance<2].sort_values(by=['distance']).domain, columns="count")

# %%
freqs.sort_values(by="count", ascending=False).index[0]
# Out:
# 'remember'

# %%
distances=[[verb,tk_quest,levenshtein_dist(verb,tk_quest)] for verb in verbs for tk_quest in tokenize(train_questions.question[preg_num])]

# %%
# distances_df=distances_df.loc[distances_df.distance>0,:]
distances_df.sort_values(by=['distance'])
# Out:
#           domain              verb question  distance
# 175     remember               why      Why       0.0
# 168     remember               who      Why       1.0
# 1374      create              plan       an       2.0
# 150     remember              when     open       2.0
# 1164      create              plan       an       2.0
# 345   understand               map       an       2.0
# 147     remember              when      Why       2.0
# 576        apply              plan       an       2.0
# 140     remember              what      Why       2.0
# 58      remember               how       an       3.0
# 56      remember               how      Why       3.0
# 177     remember               why       an       3.0
# 170     remember               who       an       3.0
# 51      remember              find       an       3.0
# 803      analyze           inspect   impact       3.0
# 165     remember             which   switch       3.0
# 448   understand              show      Why       3.0
# 161     remember             which      Why       3.0
# 343   understand               map      Why       3.0
# 561        apply             model     does       3.0
# 1066    evaluate              mark       an       3.0
# 1375      create              plan     open       3.0
# 890     evaluate              test     does       3.0
# 149     remember              when       an       3.0
# 148     remember              when     does       3.0
# 86      remember              name       an       3.0
# 142     remember              what       an       3.0
# 94      remember              omit     open       3.0
# 646      analyze              find       an       3.0
# 129     remember             spell     open       3.0
# ...          ...               ...      ...       ...
# 610      analyze      discriminate     does      11.0
# 246   understand       instantiate     does      11.0
# 392   understand       demonstrate      Why      11.0
# 245   understand       instantiate      Why      11.0
# 693      analyze       deconstruct      Why      11.0
# 612      analyze      discriminate     open      11.0
# 763      analyze       distinguish      Why      11.0
# 553        apply       make use of      Why      11.0
# 616      analyze       distinguish      Why      11.0
# 611      analyze      discriminate       an      11.0
# 319   understand       interpolate   switch      11.0
# 840      analyze      take part in      Why      12.0
# 538        apply   experiment with  circuit      12.0
# 609      analyze      discriminate      Why      12.0
# 604      analyze     differentiate       an      12.0
# 537        apply   experiment with   impact      12.0
# 535        apply   experiment with     open      12.0
# 536        apply   experiment with   switch      12.0
# 606      analyze     differentiate   switch      12.0
# 602      analyze     differentiate      Why      13.0
# 365   understand  construct models     does      13.0
# 370   understand  construct models  circuit      13.0
# 532        apply   experiment with      Why      14.0
# 534        apply   experiment with       an      14.0
# 367   understand  construct models     open      14.0
# 368   understand  construct models   switch      14.0
# 369   understand  construct models   impact      14.0
# 533        apply   experiment with     does      14.0
# 366   understand  construct models       an      15.0
# 364   understand  construct models      Why      16.0
#
# [1428 rows x 4 columns]
